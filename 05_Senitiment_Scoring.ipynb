# %% [markdown]
# <a href="https://colab.research.google.com/github/AKASH4671/Sentiment-Analysis-on-Financial-News-and-Its-Impact-on-Stock-Prices/blob/main/05_Senitiment_Scoring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Install**

# %%
# !pip install transformers
# !pip install torch
# !pip install nltk
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 22.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 30.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 40.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %% [markdown]
# **Libraries**

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import pipeline
import torch
import pandas as pd

# %% [markdown]
# **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Load data**

# %%
# Load Apple news file
news_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Finance Projects/Sentiment-Analysis-on-Financial-News-and-Its-Impact-on-Stock-Prices/data/apple_sentiment_dataset.csv")

# %% [markdown]
# **1. Hugging Face Model Hub**
# **2. Sentiment Inference Pipeline (FinBERT)**

# %%
# Load FinBERT
model_name = "yiyanghkust/finbert-tone"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# Create pipeline
nlp = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# Run sentiment scoring
sentiment_results = news_df["cleaned_text"].apply(lambda x: nlp(x)[0] if x.strip() else {'label': 'neutral', 'score': 0.0})

# Extract into separate columns
news_df["sentiment"] = sentiment_results.apply(lambda x: x['label'])
news_df["sentiment_score"] = sentiment_results.apply(lambda x: x['score'])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/533 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]
# Device set to use cpu
# model.safetensors:   0%|          | 0.00/439M [00:00<?, ?B/s]
#  Saved sentiment-scored dataset to: /content/drive/MyDrive/Colab Notebooks/Finance Projects/Sentiment-Analysis-on-Financial-News-and-Its-Impact-on-Stock-Prices/data/apple_sentiment_dataset.csv

# %%
news_df.head()
# Out:
#                   date                                           headline  \
# 0  2025-07-21 18:55:59  S&P 500 and Nasdaq hit record highs, lifted by...
# 1  2025-07-21 14:15:42  Morgan Stanley upgrades Pinterest, sees AWS an...
# 2  2025-07-21 12:48:24  DoJ to announce USA vs. GOOGL remedies any day...
# 3  2025-07-19 10:21:49  5 big analyst AI moves: Microsoft PT hike; Tes...
# 4  2025-07-19 03:31:02            Bernstein’s 15 top Asia stocks for 2H25
#
#                                              summary  \
# 0  By Noel Randewich and Nikhil Sharma (Reuters) ...
# 1  Investing.com -- Morgan Stanley raised estimat...
# 2  Investing.com -- The U.S. Department of Justic...
# 3  Investing.com -- Here are the biggest analyst ...
# 4                                                NaN
#
#                                                  url         source  \
# 0  https://www.investing.com/news/stock-market-ne...  Investing.com
# ...

# %% [markdown]
# **More Cleaning**

# %%
# Load existing full dataset
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Finance Projects/Sentiment-Analysis-on-Financial-News-and-Its-Impact-on-Stock-Prices/data/apple_sentiment_dataset.csv")

# Keep only the selected columns
df_cleaned = df[['date', 'headline', 'cleaned_text', 'sentiment', 'sentiment_score']]

# # Optional: Drop rows with missing cleaned_text
# df_cleaned = df_cleaned[df_cleaned['cleaned_text'].str.strip() != ""]

# %% [markdown]
# **Save**

# %%
# Save the cleaned version
output_path = "/content/drive/MyDrive/Colab Notebooks/Finance Projects/Sentiment-Analysis-on-Financial-News-and-Its-Impact-on-Stock-Prices/data/apple_sentiment_dataset.csv"
df_cleaned.to_csv(output_path, index=False)

print(f" Cleaned dataset saved to: {output_path}")
df_cleaned.head()
# Out:
#  Cleaned dataset saved to: /content/drive/MyDrive/Colab Notebooks/Finance Projects/Sentiment-Analysis-on-Financial-News-and-Its-Impact-on-Stock-Prices/data/apple_sentiment_dataset.csv
#                   date                                           headline  \
# 0  2025-07-21 18:55:59  S&P 500 and Nasdaq hit record highs, lifted by...
# 1  2025-07-21 14:15:42  Morgan Stanley upgrades Pinterest, sees AWS an...
# 2  2025-07-21 12:48:24  DoJ to announce USA vs. GOOGL remedies any day...
# 3  2025-07-19 10:21:49  5 big analyst AI moves: Microsoft PT hike; Tes...
# 4  2025-07-19 03:31:02            Bernstein’s 15 top Asia stocks for 2H25
#
#                                         cleaned_text sentiment  \
# 0  sp nasdaq hit record high lifted alphabet noel...  Positive
# 1  morgan stanley upgrade pinterest see aws genai...  Positive
# 2  doj announce usa v googl remedy day here expec...   Neutral
# 3  big analyst ai move microsoft pt hike tesla in...  Positive
# ...

# %%
save_path = "/content/drive/MyDrive/Colab Notebooks/Finance Projects/Sentiment-Analysis-on-Financial-News-and-Its-Impact-on-Stock-Prices/models/finbert_model"

tokenizer.save_pretrained(save_path)
model.save_pretrained(save_path)

print(f" FinBERT saved to: {save_path}")
# Out:
#  FinBERT saved to: /content/drive/MyDrive/Colab Notebooks/Finance Projects/Sentiment-Analysis-on-Financial-News-and-Its-Impact-on-Stock-Prices/models/finbert_model
